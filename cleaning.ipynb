# %% [markdown]
# To process the data, we need the libraries of pandas

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy

# %% [markdown]
# Load the csv file

# %%
df = pd.read_csv("gs://zhenjie_image_bucket/books.csv")
df.head(5)
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %% [markdown]
# Count the number of rows after droping rows with missing values on publisher

# %%
df.shape[0]
# Out:
# 8287

# %% [markdown]
# Find missing values in the column date of publication

# %%
df_with_date = df.dropna(subset=['Date of Publication'])
df_with_date.head(5)
#df_with_data.shape[0]
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %% [markdown]
# Use regular expression to find wrong formats in the colum "date of publication"

# %%
regex = "([1][0-9]{3})"

df_with_date['New Date'] = df_with_date['Date of Publication'].str.extract(regex)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_with_date['New Date']
# Out:
# 0       1879
# 1       1868
# 2       1869
# 3       1851
# 4       1857
#         ...
# 8282    1838
# 8283    1831
# 8284    1806
# 8285    1834
# 8286    1834
# Name: New Date, Length: 8106, dtype: object

# %%
plt.hist(df_with_date['Identifier'], bins=100)
# Out:
# (array([109., 104.,  95., 109.,  79.,  86.,  68.,  45.,  70.,  79.,  87.,
#          99.,  88., 182.,  90.,  61., 105.,  92.,  84., 118.,  87., 116.,
#          97.,  95.,  91.,  52.,   0.,  32.,  64.,  84.,  78.,  43.,  90.,
#          69., 100.,  80.,  81., 113.,  74.,  86.,  93.,  80., 110.,  54.,
#          90.,  65.,  90.,  69.,  43., 118.,  81.,  89.,  63.,  22.,  84.,
#         101.,  94.,  95.,  87.,  91., 115.,  66.,  88.,  53., 124.,  95.,
#          61.,  97.,  12.,  70., 104.,  99., 107.,  82.,  66.,  81.,  61.,
#          99.,  65.,  86., 128.,  69.,  94.,  82.,  72.,  94.,  99.,  77.,
#          94.,  18.,  68.,  99.,  75.,  88.,  94., 140.,  59.,   2.,  14.,
#           8.]),
#  array([2.06000000e+02, 4.18073300e+04, 8.34086600e+04, 1.25009990e+05,
#         1.66611320e+05, 2.08212650e+05, 2.49813980e+05, 2.91415310e+05,
#         3.33016640e+05, 3.74617970e+05, 4.16219300e+05, 4.57820630e+05,
#         4.99421960e+05, 5.41023290e+05, 5.82624620e+05, 6.24225950e+05,
# ...
